# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
# load the file
file_path = ("Resources/genres.csv")
df = pd.read_csv(file_path)
df.head(10)
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
# 5     1                abstract      0.459210      0.516167  3.431965e+05
# 6     1          abstract beats      0.342147      0.623000  2.299362e+05
# 7     1        abstract hip hop      0.243854      0.694571  2.318492e+05
# 8     0               accordeon      0.323000      0.588000  1.640000e+05
# 9     1               accordion      0.446125      0.624812  1.670616e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2973 entries, 0 to 2972
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   mode              2973 non-null   int64
#  1   genres            2973 non-null   object
#  2   acousticness      2973 non-null   float64
#  3   danceability      2973 non-null   float64
#  4   duration_ms       2973 non-null   float64
#  5   energy            2973 non-null   float64
#  6   instrumentalness  2973 non-null   float64
#  7   liveness          2973 non-null   float64
#  8   loudness          2973 non-null   float64
#  9   speechiness       2973 non-null   float64
#  10  tempo             2973 non-null   float64
#  11  valence           2973 non-null   float64
#  12  popularity        2973 non-null   float64
#  13  key               2973 non-null   int64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 325.3+ KB

# %%
df['genres'].unique
# Out:
# <bound method Series.unique of 0       21st century classical
# 1                        432hz
# 2                        8-bit
# 3                           []
# 4                   a cappella
#                  ...
# 2968                      zolo
# 2969                   zouglou
# 2970                      zouk
# 2971              zurich indie
# 2972                    zydeco
# Name: genres, Length: 2973, dtype: object>

# %%
df.describe()
# Out:
#               mode  acousticness  danceability   duration_ms       energy  \
# count  2973.000000   2973.000000   2973.000000  2.973000e+03  2973.000000
# mean      0.833165      0.401241      0.537187  2.517209e+05     0.561143
# std       0.372891      0.319760      0.150668  9.465686e+04     0.234486
# min       0.000000      0.000003      0.056900  3.094600e+04     0.001002
# 25%       1.000000      0.119050      0.441202  2.063788e+05     0.395058
# 50%       1.000000      0.321745      0.546496  2.375453e+05     0.601195
# 75%       1.000000      0.673991      0.647500  2.772720e+05     0.730127
# max       1.000000      0.996000      0.929000  2.382587e+06     0.994667
#
#        instrumentalness     liveness     loudness  speechiness        tempo  \
# count       2973.000000  2973.000000  2973.000000  2973.000000  2973.000000
# mean           0.211366     0.192800   -10.509848     0.083588   119.018723
# ...

# %%
# Plot the density of popularity
df['popularity'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Check popularity counts
popularity_count = df.popularity.value_counts()
popularity_count
# Out:
# 0.000000     99
# 52.000000    21
# 50.000000    21
# 49.000000    20
# 38.000000    20
#              ..
# 26.720000     1
# 39.995609     1
# 16.587972     1
# 45.779442     1
# 35.555556     1
# Name: popularity, Length: 2186, dtype: int64

# %%
# Plot popularity_count
popularity_count.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# visualize 'popularity' in a histogram
df.popularity.hist(figsize=[14,6])
# Out:
# <AxesSubplot:>

# %%
x=df.popularity

fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3,3, figsize=(15, 15))
ax1.scatter(x, df['acousticness'], s=10)
ax2.scatter(x, df['danceability'], s=10)
ax3.scatter(x, df['energy'], s=5)
ax4.scatter(x, df['instrumentalness'], s=10)
ax5.scatter(x, df['valence'], s=10)
ax6.scatter(x, df['liveness'], s=10)
ax7.scatter(x, df['speechiness'], s=10)
ax8.scatter(x, df['tempo'], s=10)
ax9.scatter(x, df['loudness'], s=10)

ax1.set_title('Popular Acousticness')
ax2.set_title('Popular Danceability')
ax3.set_title('Popular Energy')
ax4.set_title('Popular Instrumentalness')
ax5.set_title('Popular Valence')
ax6.set_title('Popular Liveness')
ax7.set_title('Popular Speechiness')
ax8.set_title('Popular Tempo')
ax9.set_title('Popular Loudness')
# Out:
# Text(0.5, 1.0, 'Popular Loudness')

# %%
df.corr()
# Out:
#                       mode  acousticness  danceability  duration_ms    energy  \
# mode              1.000000      0.077347     -0.071240    -0.053197 -0.080352
# acousticness      0.077347      1.000000     -0.324991    -0.014075 -0.868274
# danceability     -0.071240     -0.324991      1.000000    -0.160634  0.299780
# duration_ms      -0.053197     -0.014075     -0.160634     1.000000 -0.048158
# energy           -0.080352     -0.868274      0.299780    -0.048158  1.000000
# instrumentalness -0.012662      0.273739     -0.383102     0.229421 -0.324940
# liveness         -0.002650     -0.076570     -0.055147     0.018624  0.168233
# loudness         -0.063706     -0.737276      0.453062    -0.137574  0.848965
# speechiness      -0.059127     -0.086139      0.242052     0.033226  0.119791
# tempo            -0.042931     -0.397713      0.082869    -0.046840  0.430825
# valence          -0.010258     -0.178210      0.652546    -0.257517  0.305166
# ...

# %%
data = df['acousticness']
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot (data)

# show plot
plt.show()

# %%
data = df['danceability']
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot (data)
 
# show plot
plt.show()

# %%
x=df.popularity

fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3,3, figsize=(15, 15))
ax1.scatter(x, df['acousticness'], s=10)
ax2.scatter(x, df['danceability'], s=10)
ax3.scatter(x, df['energy'], s=5)
ax4.scatter(x, df['instrumentalness'], s=10)
ax5.scatter(x, df['valence'], s=10)
ax6.scatter(x, df['liveness'], s=10)
ax7.scatter(x, df['speechiness'], s=10)
ax8.scatter(x, df['tempo'], s=10)
ax9.scatter(x, df['loudness'], s=10)

ax1.set_title('Popular Acousticness')
ax2.set_title('Popular Danceability')
ax3.set_title('Popular Energy')
ax4.set_title('Popular Instrumentalness')
ax5.set_title('Popular Valence')
ax6.set_title('Popular Liveness')
ax7.set_title('Popular Speechiness')
ax8.set_title('Popular Tempo')
ax9.set_title('Popular Loudness')
# Out:
# Text(0.5, 1.0, 'Popular Loudness')

# %%
data = df['energy']
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot (data)
 
# show plot
plt.show()

# %%
data = df['instrumentalness']
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot (data)
 
# show plot
plt.show()

# %%
data = df['liveness']
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot (data)
 
# show plot
plt.show()

# %%
data = df['loudness']
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot (data)
 
# show plot
plt.show()

# %%
data = df['speechiness']
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot (data)
 
# show plot
plt.show()

# %%
data = df['tempo']
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot (data)
 
# show plot
plt.show()

# %%
data = df['valence']
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot (data)
 
# show plot
plt.show()

# %%
data = df['key']
 
fig = plt.figure(figsize =(10, 7))
 
# Creating plot
plt.boxplot (data)
 
# show plot
plt.show()

# %%
y=df['popularity']
X=df.drop(columns=["mode","genres","popularity"])

# %%
X.head()
# Out:
#    acousticness  danceability   duration_ms    energy  instrumentalness  \
# 0      0.979333      0.162883  1.602977e+05  0.071317          0.606834
# 1      0.494780      0.299333  1.048887e+06  0.450678          0.477762
# 2      0.762000      0.712000  1.151770e+05  0.818000          0.876000
# 3      0.651417      0.529093  2.328809e+05  0.419146          0.205309
# 4      0.676557      0.538961  1.906285e+05  0.316434          0.003003
#
#    liveness   loudness  speechiness       tempo   valence  key
# 0  0.361600 -31.514333     0.040567   75.336500  0.103783    6
# 1  0.131000 -16.854000     0.076817  120.285667  0.221750    5
# 2  0.126000  -9.180000     0.047000  133.444000  0.975000    7
# 3  0.218696 -12.288965     0.107872  112.857352  0.513604    7
# 4  0.172254 -12.479387     0.082851  112.110362  0.448249    7

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1)
X_train.shape
# Out:
# (2229, 11)

# %%
X_test.shape
# Out:
# (744, 11)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
results.head(20)
# Out:
#     Prediction     Actual
# 0    47.873909  48.082353
# 1    30.603473  33.598765
# 2    18.166036   3.602597
# 3    44.225966  55.625000
# 4    19.646197   0.000000
# 5    42.648349  44.961158
# 6    16.304365   0.000000
# 7    43.797099  74.979167
# 8    43.067161  40.500000
# 9    47.593806  54.700477
# 10   25.782589  11.286732
# 11   42.884178  33.455442
# 12   43.489364  39.857484
# 13   46.653610  51.490476
# 14   23.164795  33.821429
# 15   52.838743  44.900000
# 16   25.650389  46.637500
# 17   46.568702  31.000000
# 18   32.595208  43.381618
# 19   31.488322  23.633333

# %%
X_test.shape
# Out:
# (744, 11)

# %%
y_test.shape
# Out:
# (744,)

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"mean squared error (MSE): {mse}")
print(f"R-squared (R2): {r2}")
# Out:
# mean squared error (MSE): 194.88129679405608
# R-squared (R2): 0.31099508281595867

# %%
z
